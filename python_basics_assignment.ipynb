# %% [markdown]
# q1= **Explain the key features of python that makes it a popular choice for programming.**
# **Ans=** The key features that makes python a popular source of programming are:
#
#
# *   python is easy to use becuase of its readability.
# *   it has many libraries like numpy, pandas , matplotlib etc which has many in built functions.
#
# *   it also provides full fledged package to do web development, data science, machine learning, deep learning, software development and game development.
#
# **q2= Describe the role of predefined keywords in python and provide examples of how they are used in a program.**
#
# **ans2=**keywords are pre defined word that hold a special meaning and have specific purpose.
# To access the keywords in python we need to write **help(keyword)** in python ide. examples of keywords in python are True, False, if, and, break,continue etc.
#
# example:-
#
# a=10
#
# b=11
#
# if b>a:
#
#     print('yes b is greater than a')
#
# Here **if** keyword is used to give a condition to run program.
#
# **q3= Compare and contrast mutable and immutable objects in python with examples.**
#
# **ans3=**Mutable objects- These are those objects or container whose values can be changed after they are created are called mutable objects.
#
# LIST and DICTIONARY are the examples of mutable objects
#
# Immutable objects- These are those objects or container whose values cannot be changed after they are created.
#
# STRING and TUPLE are the examples of immutable objects.
#
# **q4**=**Discuss the different types of operators in python and provide examples of how they are used.**
#
# **ans4=**Types of operators in python are:
#
# 1) ARITHMETIC OPERATORS- These operators are used to do mathematical calculations in python. +, -, /,//, **, % are arithmetic operators.
#
# ex-
#
#      print(9+10)
#
#     >>19
#
# 2) COMPARISION OPERATORS-These operators are used to compare values and returns boolean values. ==, <=,>=, !=, <, > are comparision operators.
#
# ex-
#
#     >>5==5
#
#     >>True
#
# 3) LOGICAL OPERATORS-These operators are used in conditional statements and returns boolean values. AND, OR , NOT are logical operators.
#
# ex-
#
#      A=True
#
#      B= False
#
#      print(A and B)
#
#      print(A or B)
#
# 4)ASSIGNMENT OPERATOR-These operators are used to assign values of the right hand operand to left hand operand.
#
# ex=
#
#      A= 10 ( Here '=' is used to assign the value 10 to variable 'A')
#
# 5) MEMBERSHIP OPERATOR=These operators check if some member that the user is looking for , is there in string or not.
#
# ex-
#
#          a=['data','science']
#
#         'data' in a     (here IN is used to check if string 'data' is present in list a)
#       >> True
#
# 6) IDENTITY OPERATOR-It checks whether two objects are in same memory location or not and then returns boolean values.
#
# ex=
#
#      a=3
#
#      b=a
#
#      a is b
#
#      True
#
#
# 7)BITWISE OPERATOR- performs operations at bit level, manipulating individual bits within integers.
# ex=
#
#      print(6&3)
#
#      2
#
# **Q5-Explain the concept of type casting with examples.**
#
# Ans-type casting is the process of changing the data type of a value.
# The concept of type casting is used in python because while computation there can be mismatch between the data.
#
# ex-
#
#      a=('2')
#
#      b=3
#
#      ( a+b)  ( this block of code will give error because 2 is a string , to run this program 2 needs to change in integer.)
#
#       the correct program must be:
#
#      int(a)+b.
#
#      >>5
#
# **q6-How do conditional statements work in python.Illustrate with examples.**
#
# ans=conditional statements are used to run a program based on the conditions.
#
# types of conditional statement are:
#
#
# 1.   IF-
#
#      ex-
#          a=10
#
#          if a==10:
#
#               print(' this block of code will execute')
#
#
# 2.   IF-ELSE
#
#      ex-
#
#           a=10
#
#           if a>9:
#               print(' this will execute')
#
#            else:
#               print(' no is not greater than 10')
#
# 1.   IF ELIF ELSE
#
#       ex=
#            a=10
#
#            if a> 100:
#
#                print('this will execute if a is greater than 100')
#
#             elif a< 100:
#
#                   print(' this will execute if a is less than 100')
#
#            else:
#                 print ('no is equal to 100')
#
# 2.   NESTED IF ELSE
#
#      ex-
#              x=5
#              y=6
#              if x>5:
#                 if y>5:
#                     print(' both x and y is greater than y')
#                  else:
#                     print('x is greater than y but y is less than 5')
#               else:
#                   print(' x is not greater than 5')
#
# **Q7= Describe the different types of loops in python and their use cases with examples**
# Ans= Loop statements are of two types:
#
# 1) WHILE LOOP-it executes a block of code until a condition is true.
#
#  ex-
#
#        count=5
#
#        while count>0:
#
#       print(count)
#
#         count=count-1
#
#          if count==3:
#
#               break
#
#
#
# Output:
#
#          5
#          4
#
# 2) FOR LOOP- It iterates over a sequence of elements.
#
# ex-
#
#      a=['a','b','c','d','e','f']
#
#      for i in a:
#
#          if i=='b':
#
#               continue
#
#                print(i)
#
# output:
#
#          a
#          c
#          d
#          e
#          f
